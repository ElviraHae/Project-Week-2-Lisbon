# %% [markdown]
# # Basic cleaning

# %%
import pandas as pd

# %% [markdown]
# ## Cleaning Population DS

# %%
# Importing the file
original_pop_db = pd.read_excel('Population.xlsx')

original_pop_db.head(10)
# Out:
#     ANO  GEO_COD    GEO_COD_DSG  NIVEL       NIVEL_DSG  N_INDIVIDUOS_RESIDENT  \
# 0  2011      'PT             PT      1  Total Nacional               10562178
# 1  2011       '1     Continente      2            NUT1               10047621
# 2  2011      '17         Lisboa      3            NUT2                2821876
# 3  2011     '171  Grande Lisboa      4            NUT3                2042477
# 4  2011    '1106         Lisboa      5       Municipio                 547733
# 5  2011  '110601          Ajuda      6       Freguesia                  15584
# 6  2011  '110602      Alcântara      6       Freguesia                  13943
# 7  2011  '110603   Alto do Pina      6       Freguesia                  10333
# 8  2011  '110604       Alvalade      6       Freguesia                   8869
# 9  2011  '110605     Ameixoeira      6               ,                  11863
#
#    N_INDIVIDUOS_RESIDENT_H  N_INDIVIDUOS_RESIDENT_M
# 0                  5046600                  5515578
# 1                  4798798                  5248823
# 2                  1334605                  1487271
# 3                   961132                  1081345
# 4                   250874                   296859
# 5                     7120                     8464
# 6                     6254                     7689
# 7                     4687                     5646
# 8                     3764                     5105
# 9                     5568                     6295

# %%
# Selecting just the cols that we want to display
pop_db = original_pop_db[['GEO_COD_DSG', 'NIVEL_DSG', 'N_INDIVIDUOS_RESIDENT']]


# Filtering to just get the rows which match 'Freguesia' - helped to get rid of all blank values
pop_db = pop_db[(pop_db['NIVEL_DSG'] == 'Freguesia')]


# Selecting new cols that we want
pop_db = pop_db[['GEO_COD_DSG', 'N_INDIVIDUOS_RESIDENT']]

pop_db.head(10)
# Out:
#      GEO_COD_DSG  N_INDIVIDUOS_RESIDENT
# 5          Ajuda                  15584
# 6      Alcântara                  13943
# 7   Alto do Pina                  10333
# 8       Alvalade                   8869
# 10         Anjos                   9361
# 11         Beato                  12429
# 12       Benfica                  36821
# 13  Campo Grande                  10514
# 14     Campolide                  15460
# 15       Carnide                  23316

# %%
# Renaming the columns
pop_db.columns = ['FREGUESIAS', 'TOTAL RESIDENTS']


# Making 'FREGUESIAS' column have .upper values
pop_db['FREGUESIAS'] = pop_db['FREGUESIAS'].str.upper()

pop_db.head(10)
# Out:
#       FREGUESIAS  TOTAL RESIDENTS
# 5          AJUDA            15584
# 6      ALCÂNTARA            13943
# 7   ALTO DO PINA            10333
# 8       ALVALADE             8869
# 10         ANJOS             9361
# 11         BEATO            12429
# 12       BENFICA            36821
# 13  CAMPO GRANDE            10514
# 14     CAMPOLIDE            15460
# 15       CARNIDE            23316

# %%
pop_db.shape
# Out:
# (52, 2)

# %% [markdown]
# ## Cleaning Freguesias DS

# %%
# Importing the file
original_freguesias_db = pd.read_csv('Freguesias2012.csv')


original_freguesias_db['FREGUESIAS53'] = original_freguesias_db['FREGUESIAS53'].str.upper()
original_freguesias_db.head(10)
# Out:
#    OBJECTID  COD_SIG               NOME  IDTIPO  PERIMETRO      AREA_M2  \
# 0         1      122      Santo António    4015    6313.94   1494348.58
# 1         2      118  Parque das Nações    4015   12237.24   5435124.30
# 2         3      115            Marvila    4015   12216.54   7122521.90
# 3         4      101              Ajuda    4015    9153.10   2876647.11
# 4         5      104            Areeiro    4015    6358.83   1719002.47
# 5         6      121  Santa Maria Maior    4015    9306.07   3011591.52
# 6         7      103           Alvalade    4015   10751.30   5341751.02
# 7         8      108              Belém    4015   16050.78  10426948.88
# 8         9      113            Estrela    4015    9927.92   4604095.97
# 9        10      105            Arroios    4015    8240.38   2127871.88
#
#                                         FREGUESIAS53  \
# 0           CORAÇÃO DE JESUS + SÃO JOSÉ + SÃO MAMEDE
# 1                           SANTA MARIA DOS OLIVAIS
# 2                                            MARVILA
# 3                                              AJUDA
# 4                    ALTO DO PINA + SÃO JOÃO DE DEUS
# 5  CASTELO + MADALENA + MÁRTIRES + SACRAMENTO + S...
# 6        ALVALADE + CAMPO GRANDE + SÃO JOÃO DE BRITO
# 7        SANTA MARIA DE BELÉM + SÃO FRANCISCO XAVIER
# 8                   LAPA + PRAZERES + SANTOS-O-VELHO
# 9                ANJOS + PENA + SÃO JORGE DE ARROIOS
#
#                                GlobalID   Shape__Area  Shape__Length
# 0  9de1ceba-f851-4181-a39b-a4f8bc15f3c5  2.458057e+06    8097.074172
# 1  aee6efb3-c624-4d82-b5f8-a98c4444b8c6  8.953807e+06   15724.284710
# 2  d6c144c0-6ffc-46d7-b6bf-f10fa7977b89  1.172476e+07   15674.400259
# 3  cdcaeb5c-7228-4a89-9091-9fb9be097e6e  4.730508e+06   11740.588160
# 4  d1e276ef-009e-4290-a8b8-73643141a71e  2.829203e+06    8153.225327
# 5  60af311b-84fb-4a39-856a-291d65993f97  4.952034e+06   11936.070712
# 6  e9ec7868-7b40-478a-87b3-c6ad6e373e5a  8.794657e+06   13786.968033
# 7  3a6d0af1-130a-4c90-80f6-b6017dac1ca1  1.713895e+07   20577.231795
# 8  ba35868d-aa59-40db-8737-469f48274ce9  7.569528e+06   12734.386771
# 9  ec8fa8b1-49e5-49bb-a311-1f51aafa5e77  3.500783e+06   10572.552949

# %%
# Selecting the cols that we want to keep
freguesias_db = original_freguesias_db[['NOME', 'AREA_M2', 'FREGUESIAS53']]


# Renaming the cols
freguesias_db.columns = ['CURRENT FREGUESIAS', 'AREA', 'OLD FREGUESIAS']


# Making the Freguesias names be .upper()

freguesias_db['CURRENT FREGUESIAS'] = freguesias_db['CURRENT FREGUESIAS'].str.upper()


freguesias_db.head(10)
# Out:
# /Users/mattymrc/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#   CURRENT FREGUESIAS         AREA  \
# 0      SANTO ANTÓNIO   1494348.58
# 1  PARQUE DAS NAÇÕES   5435124.30
# 2            MARVILA   7122521.90
# 3              AJUDA   2876647.11
# 4            AREEIRO   1719002.47
# 5  SANTA MARIA MAIOR   3011591.52
# 6           ALVALADE   5341751.02
# 7              BELÉM  10426948.88
# 8            ESTRELA   4604095.97
# 9            ARROIOS   2127871.88
#
#                                       OLD FREGUESIAS
# 0           CORAÇÃO DE JESUS + SÃO JOSÉ + SÃO MAMEDE
# 1                           SANTA MARIA DOS OLIVAIS
# 2                                            MARVILA
# 3                                              AJUDA
# 4                    ALTO DO PINA + SÃO JOÃO DE DEUS
# 5  CASTELO + MADALENA + MÁRTIRES + SACRAMENTO + S...
# 6        ALVALADE + CAMPO GRANDE + SÃO JOÃO DE BRITO
# 7        SANTA MARIA DE BELÉM + SÃO FRANCISCO XAVIER
# 8                   LAPA + PRAZERES + SANTOS-O-VELHO
# 9                ANJOS + PENA + SÃO JORGE DE ARROIOS

# %% [markdown]
# ## Cleaning Public Lighting DS

# %%
# Importing the file
original_lights_db = pd.read_csv('Candeeiros.csv')

original_lights_db.head(10)
# Out:
#           X          Y  OBJECTID_1          FREGUESIA TIPOLOGIA      COD_SIG  \
# 0 -9.141983  38.710343        2001  SANTA MARIA MAIOR   Consola  320058790.0
# 1 -9.142045  38.709027        2002  SANTA MARIA MAIOR   Consola  320059024.0
# 2 -9.141898  38.709226        2003  SANTA MARIA MAIOR   Consola  320058467.0
# 3 -9.141974  38.709676        2004  SANTA MARIA MAIOR   Consola  320058468.0
# 4 -9.139831  38.722655        2005            ARROIOS    Coluna  320058551.0
# 5 -9.139617  38.722630        2006            ARROIOS    Coluna  320058078.0
# 6 -9.139928  38.722669        2007            ARROIOS    Coluna  320058181.0
# 7 -9.140245  38.722624        2008            ARROIOS    Coluna  320058141.0
# 8 -9.140179  38.722510        2009            ARROIOS    Coluna  320058552.0
# 9 -9.140049  38.722626        2010            ARROIOS    Coluna  320058182.0
#
#                          MORADA                              GlobalID
# 0          Rua Paiva de Andrada  52dcd30e-57f5-453c-9455-deb7784e97d9
# 1            Largo do Picadeiro  d14a744d-b274-4253-9820-5db4e22072ae
# 2            Largo do Picadeiro  b2689a5a-ce30-44b2-b70c-7de1eb9fdadf
# 3            Largo do Picadeiro  4e3d4e6a-0cfc-4029-b127-d375b80a6e90
# 4  Campo dos Mártires da Pátria  d3aef766-296b-4d94-bf2d-92b2c5dd1691
# 5  Campo dos Mártires da Pátria  90f4b46a-5bdd-44e1-9bf7-f7659304c481
# 6  Campo dos Mártires da Pátria  a63d3be0-dcc2-4723-ad28-7081c55472dc
# 7  Campo dos Mártires da Pátria  041912a9-7f2b-4af7-958e-0a7b7b85ddd6
# 8  Campo dos Mártires da Pátria  2dc9338e-30fe-4b1c-92ec-7c55bed91b74
# 9  Campo dos Mártires da Pátria  f9654514-3675-4c30-9b4d-03ea9f4a655e

# %%
# Selecting the cols we want
lights_db = original_lights_db[['OBJECTID_1', 'FREGUESIA', 'MORADA']]


# Renaming the cols
lights_db.columns = ['OBJECT NUMBER', 'FREGUESIA', 'ADDRESS']


lights_db.head(10)
# Out:
#    OBJECT NUMBER          FREGUESIA                       ADDRESS
# 0           2001  SANTA MARIA MAIOR          Rua Paiva de Andrada
# 1           2002  SANTA MARIA MAIOR            Largo do Picadeiro
# 2           2003  SANTA MARIA MAIOR            Largo do Picadeiro
# 3           2004  SANTA MARIA MAIOR            Largo do Picadeiro
# 4           2005            ARROIOS  Campo dos Mártires da Pátria
# 5           2006            ARROIOS  Campo dos Mártires da Pátria
# 6           2007            ARROIOS  Campo dos Mártires da Pátria
# 7           2008            ARROIOS  Campo dos Mártires da Pátria
# 8           2009            ARROIOS  Campo dos Mártires da Pátria
# 9           2010            ARROIOS  Campo dos Mártires da Pátria

# %%
# Checking the shape
lights_db.shape
# Out:
# (62840, 3)

# %% [markdown]
# # NEW THINGS FROM HERE ON

# %% [markdown]
# ## Cleaning Health Centers DS

# %%
original_health_db = pd.read_csv('Health centers.csv')

# %%
#selecting the columns with the data that we need

health_db = original_health_db[['ACTIVIDADE_NOME', 'FREGUESIA']]
health_db.columns = ['Health Center', 'Freguesia']
health_db.head(10)
# Out:
#                                     Health Center          Freguesia
# 0                                 Centro de Saúde              Belém
# 1                          Centro de Saúde Lumiar             Lumiar
# 2                          Centro de Saúde Lumiar             Lumiar
# 3                                 Centro de Saúde              Belém
# 4                                 Centro de Saúde              Belém
# 5  Centro de Saúde de Sete Rios - Ext.Sãvida /EDP     Avenidas Novas
# 6                     Centro de Saúde de São João    Penha de França
# 7              Unidade de Saúde Familiar da Baixa  Santa Maria Maior
# 8                   Clínica Médica Ferreira Diniz              Belém
# 9                      Laboratório de Pneumologia          Alcântara

# %% [markdown]
# ## Cleaning Police DS

# %%
# Importing the dataset
original_police_db = pd.read_csv('Police stations.csv')

original_police_db.head(5)
# Out:
#           X          Y  OBJECTID           COD_SIG  IDTIPO   COD_SIG_EDIF  \
# 0 -9.124780  38.752021         1  2105705006001021     999  2105705006001
# 1 -9.135952  38.717907         2  3100303072001001     999  3100303072001
# 2 -9.126077  38.739351         3   302704025001001     999   302704025001
# 3 -9.151055  38.726657         4  5001301001001002     999  5001301001001
# 4 -9.136034  38.709358         5  1900102007001004     999  1900102007001
#
#                                NOME  \
# 0                      38ª Esquadra
# 1  Comando - 1ª Divisão Policial LX
# 2                      12ª Esquadra
# 3      Parque de Viaturas Rebocadas
# 4                       2ª Esquadra
#
#                                               MORADA         TIPO_UNIDADE  \
# 0               Rua Ricardo Ornelas  Lote 378, R/C-A  Esquadra de Polícia
# 1                                  Rua da Palma, 169              Comando
# 2                    Largo Roque Laia 3A, R/C Loja A  Esquadra de Polícia
# 3           Alameda Edgar Cardoso Estacionamento, -1               Vários
# 4  Rua da Prata nº 38, 1100-419 Lisboa c/ Rua de ...  Esquadra de Polícia
#
#     TELEFONE EMAIL CODPOSTAL FONTE  \
# 0          -     -         -   PSP
# 1  213513600     -  1100-391   PSP
# 2          -     -         -   PSP
# 3          -     -         -   PSP
# 4  213427379     -  1100-524   PSP
#
#                                          MORADA_RMOG  \
# 0  Rua Ricardo Ornelas (antigo Impasse A4 do B. F...
# 1                              Rua da Palma 169, R/C
# 2                    Largo Roque Laia 3A, R/C-Loja A
# 3           Alameda Edgar Cardoso Estacionamento, -1
# 4                               Rua da Prata 38, R/C
#
#                                GlobalID
# 0  21788845-91be-4b5d-af40-f183b0016061
# 1  801d5d4e-4943-421e-accb-23f56dc0d0ad
# 2  cc8b174b-fb7e-45f9-af5f-bbc406846953
# 3  23a42e6b-cb83-47fb-b8cb-6ec6d785cda9
# 4  6875624f-dec8-4ed4-9c4d-dd16995b3df3

# %%
#selecting the only columns that we need
police_db = original_police_db[['NOME', 'MORADA','CODPOSTAL']]
police_db.head(5)
# Out:
#                                NOME  \
# 0                      38ª Esquadra
# 1  Comando - 1ª Divisão Policial LX
# 2                      12ª Esquadra
# 3      Parque de Viaturas Rebocadas
# 4                       2ª Esquadra
#
#                                               MORADA CODPOSTAL
# 0               Rua Ricardo Ornelas  Lote 378, R/C-A         -
# 1                                  Rua da Palma, 169  1100-391
# 2                    Largo Roque Laia 3A, R/C Loja A         -
# 3           Alameda Edgar Cardoso Estacionamento, -1         -
# 4  Rua da Prata nº 38, 1100-419 Lisboa c/ Rua de ...  1100-524

# %%
# Checking which lines have no postcode
nopostcode = police_db[police_db['CODPOSTAL'] == '-']

nopostcode
# Out:
#                             NOME  \
# 0                   38ª Esquadra
# 2                   12ª Esquadra
# 3   Parque de Viaturas Rebocadas
# 5              Secção de Achados
# 81           Esquadra de Turismo
#
#                                                MORADA CODPOSTAL
# 0                Rua Ricardo Ornelas  Lote 378, R/C-A         -
# 2                     Largo Roque Laia 3A, R/C Loja A         -
# 3            Alameda Edgar Cardoso Estacionamento, -1         -
# 5   Alameda das Comunidades Portuguesas Terminal 1...         -
# 81                       Largo do Museu de Artilharia         -

# %%
# Checking the shape
police_db.shape
# Out:
# (90, 3)

# %%
# Finding duplicated addresses and removing them. Consider these as one police division
police_db.drop_duplicates(subset = "MORADA", keep = False, inplace = True)

police_db
# Out:
# /Users/mattymrc/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                  NOME  \
# 0                                        38ª Esquadra
# 2                                        12ª Esquadra
# 3                        Parque de Viaturas Rebocadas
# 4                                         2ª Esquadra
# 5                                   Secção de Achados
# 16  Divisão Policial de Segurança a Transportes Pú...
# 17    1ª Esquadra de Segurança a Transportes Públicos
# 18                  Esquadra de Investigação Criminal
# 19           Tribunal de Monsanto - Esquadra Especial
# 21    4º Esquadra de Segurança a Transportes Públicos
# 26  Direção Nacional da PSP - Departamento de Arma...
# 27  Instituto Superior de Ciências Policiais e Seg...
# 28     Carreira de Tiro da Escola Superior de Polícia
# 29                               Corpo de Intervenção
# 30                                  Secção de Achados
# 31                                Esquadra de Turismo
# 32                                   Posto de Polícia
# 33                                   Posto de Polícia
# 34                                   Posto de Polícia
# 35                       Parque de Viaturas Rebocadas
# 36                       Parque de Viaturas Rebocadas
# 37                                  Polícia Municipal
# 38                                        3ª Esquadra
# 40                                    22ª Esquadra LX
# 41                             2ª Divisão Policial LX
# 43    Esquadra de Intervenção e Fiscalização Policial
# 44                                    14ª Esquadra LX
# 45                                    16ª Esquadra LX
# 47                                       40ª Esquadra
# 48                             3ª Divisão Policial LX
# 49                              Esquadra de Segurança
# 50                              Esquadra de Segurança
# 51                              Esquadra de Segurança
# 52                              Esquadra de Segurança
# 53                              Esquadra de Segurança
# 56    Esquadra de Intervenção e Fiscalização Policial
# 57                                    18ª Esquadra LX
# 58                                    19ª Esquadra LX
# 59                                    20ª Esquadra LX
# 60                                    21ª Esquadra LX
# 61                                       32ª Esquadra
# 62                                       36ª Esquadra
# 63                                       37ª Esquadra
# 64                                       41ª Esquadra
# 65                                       42ª Esquadra
# 66                                    43ª Esquadra LX
# 67                                   Posto de Polícia
# 68                                4ª Divisão Policial
# 71                                    24ª Esquadra LX
# 72                                    26ª Esquadra LX
# 73                                    28ª Esquadra LX
# 74                                       30ª Esquadra
# 78                                    10ª Esquadra Lx
# 80                                    12ª Esquadra LX
# 81                                Esquadra de Turismo
#
#                                                MORADA CODPOSTAL
# 0                Rua Ricardo Ornelas  Lote 378, R/C-A         -
# 2                     Largo Roque Laia 3A, R/C Loja A         -
# 3            Alameda Edgar Cardoso Estacionamento, -1         -
# 4   Rua da Prata nº 38, 1100-419 Lisboa c/ Rua de ...  1100-524
# 5   Alameda das Comunidades Portuguesas Terminal 1...         -
# 16             Estação CP Rossio Ed. Posto do Comando  1200-147
# 17  Praça do Marquês de Pombal Estação de Metro (M...  1250-161
# 18    Estação CP Rossio, Edifício do Chefe da Estação  1200-147
# 19               Estrada do Forte (Monsanto) Tribunal  1500-624
# 21  Avenida Dom João II, Estação do Oriente Lt. 01...  1990-233
# 26              Travessa da Fábrica dos Pentes 22, 1º  1269-003
# 27           Rua  Primeiro de Maio a Alcântara  3 R/C  1349-040
# 28            Rua Primeiro de Maio a Alcântara  3 R/C  1349-040
# 29                               Calçada da Ajuda, 23  1300-006
# 30              Praça Cidade de Salazar Lote 180, R/C  1800-125
# 31              Praça dos Restauradores - Palácio Foz  1250-187
# 32        Rua José António Serrano Bloco Central, R/C  1150-199
# 33  Avenida  Professor Egas Moniz  Hospital de San...  1649-035
# 34  Estrada do Forte do Alto do Duque Hospital S F...  1449-005
# 35                        Azinhaga Torre do Fato, s/n  1600-298
# 36                            Rua Gregório Lopes, PSP  1400-195
# 37                           Rua Cardeal Saraiva, R/C  1070-045
# 38  Rua da Atalaia 138-144, R/C, Rua de O Século  ...  1200-033
# 40                                   Largo do Rato, 1  1250-185
# 41  Rua Cidade de Nampula (antiga Rua B2 de Olivai...  1800-105
# 43         Avenida Cidade Lourenço Marques, Praceta A  1800-093
# 44                          Rua Luiz Pacheco Lote 105  1950-244
# 45                Avenida João Paulo II Lote 526, R/C  1950-159
# 47  Rua Ilha dos Amores, Lote 43901-J, Parque das ...  1990-371
# 48                          Rua André de Resende, R/C  1500-040
# 49                              Palácio de Belém, s/n  1349-022
# 50                            Praça de São Bento, s/n  1249-068
# 51                Rua Professor Gomes Teixeira 2, R/C  1350-265
# 52                       Rua da Imprensa à Estrela, 4  1200-888
# 53         Avenida João Crisóstomo Casa da Moeda, R/C  1500-624
# 56                            Rua André de Resende, 1  1500-040
# 57                    Rua Afonso Lopes Vieira 2A, R/C  1700-093
# 58  Rua Professor Luís Reis dos Santos, Lote H - 4...  1600-641
# 59                             Rua André de Resende 1  1500-040
# 60  Rua Marquês de Fronteira Tribunal da Policia, ...  1098-001
# 61  Rua Alfredo Ferraz (antigo Impasse B1 do Bairr...  1600-003
# 62  Rua Prof. Miller Guerra (antigo Impasse A do B...  1600-647
# 63                Rua Miguel Ângelo de Blasco 25, R/C  1070-181
# 64  Rua Maria José da Guia, 14 B - Bairro da Cruz ...  1750-358
# 65                          Rua Manuela Porto, 14 - A  1500-422
# 66  Rua do Azevinho (Rua B) Quarteirão Central B -...  1500-536
# 67  Rua Albert Einstein (antiga R Norte - C.C.Colo...  1500-676
# 68                            Largo do Calvário 6, 1º  1300-113
# 71                            Rua Azedo Gneco 84, R/C  1350-039
# 72               Praça Afonso de Albuquerque PSP, R/C  1300-004
# 73                           Largo do Calvário 6, R/C  1300-113
# 74                             Rua Miguel Lupi 6, R/C  1200-725
# 78                            Rua de Arroios, 164 - A  1000-061
# 80                          Rua Américo Durão, 3, A-B  1900-063
# 81                       Largo do Museu de Artilharia         -

# %%
#drop all rows with - on postal code
police_db.drop(police_db[police_db['CODPOSTAL'] == '-'].index, axis=0, inplace=True)
# Out:
# /Users/mattymrc/.pyenv/versions/3.7.5/lib/python3.7/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#resetting the index
police_db.reset_index(drop=True, inplace=True)
police_db
# Out:
#                                                  NOME  \
# 0                                         2ª Esquadra
# 1   Divisão Policial de Segurança a Transportes Pú...
# 2     1ª Esquadra de Segurança a Transportes Públicos
# 3                   Esquadra de Investigação Criminal
# 4            Tribunal de Monsanto - Esquadra Especial
# 5     4º Esquadra de Segurança a Transportes Públicos
# 6   Direção Nacional da PSP - Departamento de Arma...
# 7   Instituto Superior de Ciências Policiais e Seg...
# 8      Carreira de Tiro da Escola Superior de Polícia
# 9                                Corpo de Intervenção
# 10                                  Secção de Achados
# 11                                Esquadra de Turismo
# 12                                   Posto de Polícia
# 13                                   Posto de Polícia
# 14                                   Posto de Polícia
# 15                       Parque de Viaturas Rebocadas
# 16                       Parque de Viaturas Rebocadas
# 17                                  Polícia Municipal
# 18                                        3ª Esquadra
# 19                                    22ª Esquadra LX
# 20                             2ª Divisão Policial LX
# 21    Esquadra de Intervenção e Fiscalização Policial
# 22                                    14ª Esquadra LX
# 23                                    16ª Esquadra LX
# 24                                       40ª Esquadra
# 25                             3ª Divisão Policial LX
# 26                              Esquadra de Segurança
# 27                              Esquadra de Segurança
# 28                              Esquadra de Segurança
# 29                              Esquadra de Segurança
# 30                              Esquadra de Segurança
# 31    Esquadra de Intervenção e Fiscalização Policial
# 32                                    18ª Esquadra LX
# 33                                    19ª Esquadra LX
# 34                                    20ª Esquadra LX
# 35                                    21ª Esquadra LX
# 36                                       32ª Esquadra
# 37                                       36ª Esquadra
# 38                                       37ª Esquadra
# 39                                       41ª Esquadra
# 40                                       42ª Esquadra
# 41                                    43ª Esquadra LX
# 42                                   Posto de Polícia
# 43                                4ª Divisão Policial
# 44                                    24ª Esquadra LX
# 45                                    26ª Esquadra LX
# 46                                    28ª Esquadra LX
# 47                                       30ª Esquadra
# 48                                    10ª Esquadra Lx
# 49                                    12ª Esquadra LX
#
#                                                MORADA CODPOSTAL
# 0   Rua da Prata nº 38, 1100-419 Lisboa c/ Rua de ...  1100-524
# 1              Estação CP Rossio Ed. Posto do Comando  1200-147
# 2   Praça do Marquês de Pombal Estação de Metro (M...  1250-161
# 3     Estação CP Rossio, Edifício do Chefe da Estação  1200-147
# 4                Estrada do Forte (Monsanto) Tribunal  1500-624
# 5   Avenida Dom João II, Estação do Oriente Lt. 01...  1990-233
# 6               Travessa da Fábrica dos Pentes 22, 1º  1269-003
# 7            Rua  Primeiro de Maio a Alcântara  3 R/C  1349-040
# 8             Rua Primeiro de Maio a Alcântara  3 R/C  1349-040
# 9                                Calçada da Ajuda, 23  1300-006
# 10              Praça Cidade de Salazar Lote 180, R/C  1800-125
# 11              Praça dos Restauradores - Palácio Foz  1250-187
# 12        Rua José António Serrano Bloco Central, R/C  1150-199
# 13  Avenida  Professor Egas Moniz  Hospital de San...  1649-035
# 14  Estrada do Forte do Alto do Duque Hospital S F...  1449-005
# 15                        Azinhaga Torre do Fato, s/n  1600-298
# 16                            Rua Gregório Lopes, PSP  1400-195
# 17                           Rua Cardeal Saraiva, R/C  1070-045
# 18  Rua da Atalaia 138-144, R/C, Rua de O Século  ...  1200-033
# 19                                   Largo do Rato, 1  1250-185
# 20  Rua Cidade de Nampula (antiga Rua B2 de Olivai...  1800-105
# 21         Avenida Cidade Lourenço Marques, Praceta A  1800-093
# 22                          Rua Luiz Pacheco Lote 105  1950-244
# 23                Avenida João Paulo II Lote 526, R/C  1950-159
# 24  Rua Ilha dos Amores, Lote 43901-J, Parque das ...  1990-371
# 25                          Rua André de Resende, R/C  1500-040
# 26                              Palácio de Belém, s/n  1349-022
# 27                            Praça de São Bento, s/n  1249-068
# 28                Rua Professor Gomes Teixeira 2, R/C  1350-265
# 29                       Rua da Imprensa à Estrela, 4  1200-888
# 30         Avenida João Crisóstomo Casa da Moeda, R/C  1500-624
# 31                            Rua André de Resende, 1  1500-040
# 32                    Rua Afonso Lopes Vieira 2A, R/C  1700-093
# 33  Rua Professor Luís Reis dos Santos, Lote H - 4...  1600-641
# 34                             Rua André de Resende 1  1500-040
# 35  Rua Marquês de Fronteira Tribunal da Policia, ...  1098-001
# 36  Rua Alfredo Ferraz (antigo Impasse B1 do Bairr...  1600-003
# 37  Rua Prof. Miller Guerra (antigo Impasse A do B...  1600-647
# 38                Rua Miguel Ângelo de Blasco 25, R/C  1070-181
# 39  Rua Maria José da Guia, 14 B - Bairro da Cruz ...  1750-358
# 40                          Rua Manuela Porto, 14 - A  1500-422
# 41  Rua do Azevinho (Rua B) Quarteirão Central B -...  1500-536
# 42  Rua Albert Einstein (antiga R Norte - C.C.Colo...  1500-676
# 43                            Largo do Calvário 6, 1º  1300-113
# 44                            Rua Azedo Gneco 84, R/C  1350-039
# 45               Praça Afonso de Albuquerque PSP, R/C  1300-004
# 46                           Largo do Calvário 6, R/C  1300-113
# 47                             Rua Miguel Lupi 6, R/C  1200-725
# 48                            Rua de Arroios, 164 - A  1000-061
# 49                          Rua Américo Durão, 3, A-B  1900-063

# %%
#creating new columns for Freguesias
police_db['Freguesia'] = police_db['CODPOSTAL']
# Out:
# /Users/mattymrc/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#dropping police estalishments that are not stations
police_db.drop(police_db[police_db['NOME'] == 'Secção de Achados'].index, axis=0, inplace=True)
police_db.drop(police_db[police_db['NOME'] == 'Instituto Superior de Ciências Policiais e Segurança Interna'].index, axis=0, inplace=True)
police_db.drop(police_db[police_db['NOME'] == 'Parque de Viaturas Rebocadas'].index, axis=0, inplace=True)
police_db.drop(police_db[police_db['NOME'] == 'Carreira de Tiro da Escola Superior de Polícia'].index, axis=0, inplace=True)

# %%
#resetting index
police_db.reset_index(drop=True, inplace=True)
police_db
# Out:
#                                                  NOME  \
# 0                                         2ª Esquadra
# 1   Divisão Policial de Segurança a Transportes Pú...
# 2     1ª Esquadra de Segurança a Transportes Públicos
# 3                   Esquadra de Investigação Criminal
# 4            Tribunal de Monsanto - Esquadra Especial
# 5     4º Esquadra de Segurança a Transportes Públicos
# 6   Direção Nacional da PSP - Departamento de Arma...
# 7                                Corpo de Intervenção
# 8                                 Esquadra de Turismo
# 9                                    Posto de Polícia
# 10                                   Posto de Polícia
# 11                                   Posto de Polícia
# 12                                  Polícia Municipal
# 13                                        3ª Esquadra
# 14                                    22ª Esquadra LX
# 15                             2ª Divisão Policial LX
# 16    Esquadra de Intervenção e Fiscalização Policial
# 17                                    14ª Esquadra LX
# 18                                    16ª Esquadra LX
# 19                                       40ª Esquadra
# 20                             3ª Divisão Policial LX
# 21                              Esquadra de Segurança
# 22                              Esquadra de Segurança
# 23                              Esquadra de Segurança
# 24                              Esquadra de Segurança
# 25                              Esquadra de Segurança
# 26    Esquadra de Intervenção e Fiscalização Policial
# 27                                    18ª Esquadra LX
# 28                                    19ª Esquadra LX
# 29                                    20ª Esquadra LX
# 30                                    21ª Esquadra LX
# 31                                       32ª Esquadra
# 32                                       36ª Esquadra
# 33                                       37ª Esquadra
# 34                                       41ª Esquadra
# 35                                       42ª Esquadra
# 36                                    43ª Esquadra LX
# 37                                   Posto de Polícia
# 38                                4ª Divisão Policial
# 39                                    24ª Esquadra LX
# 40                                    26ª Esquadra LX
# 41                                    28ª Esquadra LX
# 42                                       30ª Esquadra
# 43                                    10ª Esquadra Lx
# 44                                    12ª Esquadra LX
#
#                                                MORADA CODPOSTAL Freguesia
# 0   Rua da Prata nº 38, 1100-419 Lisboa c/ Rua de ...  1100-524  1100-524
# 1              Estação CP Rossio Ed. Posto do Comando  1200-147  1200-147
# 2   Praça do Marquês de Pombal Estação de Metro (M...  1250-161  1250-161
# 3     Estação CP Rossio, Edifício do Chefe da Estação  1200-147  1200-147
# 4                Estrada do Forte (Monsanto) Tribunal  1500-624  1500-624
# 5   Avenida Dom João II, Estação do Oriente Lt. 01...  1990-233  1990-233
# 6               Travessa da Fábrica dos Pentes 22, 1º  1269-003  1269-003
# 7                                Calçada da Ajuda, 23  1300-006  1300-006
# 8               Praça dos Restauradores - Palácio Foz  1250-187  1250-187
# 9         Rua José António Serrano Bloco Central, R/C  1150-199  1150-199
# 10  Avenida  Professor Egas Moniz  Hospital de San...  1649-035  1649-035
# 11  Estrada do Forte do Alto do Duque Hospital S F...  1449-005  1449-005
# 12                           Rua Cardeal Saraiva, R/C  1070-045  1070-045
# 13  Rua da Atalaia 138-144, R/C, Rua de O Século  ...  1200-033  1200-033
# 14                                   Largo do Rato, 1  1250-185  1250-185
# 15  Rua Cidade de Nampula (antiga Rua B2 de Olivai...  1800-105  1800-105
# 16         Avenida Cidade Lourenço Marques, Praceta A  1800-093  1800-093
# 17                          Rua Luiz Pacheco Lote 105  1950-244  1950-244
# 18                Avenida João Paulo II Lote 526, R/C  1950-159  1950-159
# 19  Rua Ilha dos Amores, Lote 43901-J, Parque das ...  1990-371  1990-371
# 20                          Rua André de Resende, R/C  1500-040  1500-040
# 21                              Palácio de Belém, s/n  1349-022  1349-022
# 22                            Praça de São Bento, s/n  1249-068  1249-068
# 23                Rua Professor Gomes Teixeira 2, R/C  1350-265  1350-265
# 24                       Rua da Imprensa à Estrela, 4  1200-888  1200-888
# 25         Avenida João Crisóstomo Casa da Moeda, R/C  1500-624  1500-624
# 26                            Rua André de Resende, 1  1500-040  1500-040
# 27                    Rua Afonso Lopes Vieira 2A, R/C  1700-093  1700-093
# 28  Rua Professor Luís Reis dos Santos, Lote H - 4...  1600-641  1600-641
# 29                             Rua André de Resende 1  1500-040  1500-040
# 30  Rua Marquês de Fronteira Tribunal da Policia, ...  1098-001  1098-001
# 31  Rua Alfredo Ferraz (antigo Impasse B1 do Bairr...  1600-003  1600-003
# 32  Rua Prof. Miller Guerra (antigo Impasse A do B...  1600-647  1600-647
# 33                Rua Miguel Ângelo de Blasco 25, R/C  1070-181  1070-181
# 34  Rua Maria José da Guia, 14 B - Bairro da Cruz ...  1750-358  1750-358
# 35                          Rua Manuela Porto, 14 - A  1500-422  1500-422
# 36  Rua do Azevinho (Rua B) Quarteirão Central B -...  1500-536  1500-536
# 37  Rua Albert Einstein (antiga R Norte - C.C.Colo...  1500-676  1500-676
# 38                            Largo do Calvário 6, 1º  1300-113  1300-113
# 39                            Rua Azedo Gneco 84, R/C  1350-039  1350-039
# 40               Praça Afonso de Albuquerque PSP, R/C  1300-004  1300-004
# 41                           Largo do Calvário 6, R/C  1300-113  1300-113
# 42                             Rua Miguel Lupi 6, R/C  1200-725  1200-725
# 43                            Rua de Arroios, 164 - A  1000-061  1000-061
# 44                          Rua Américo Durão, 3, A-B  1900-063  1900-063

# %%
#inserting freguesia name
police_db.at[0, 'Freguesia'] = 'São Nicolau'
police_db.at[1, 'Freguesia'] = 'Santo António'
police_db.at[2, 'Freguesia'] = 'Santa Maria Maior'
police_db.at[3, 'Freguesia'] = 'Santo António'
police_db.at[4, 'Freguesia'] = 'Benfica'
police_db.at[5, 'Freguesia'] = 'Olivais'
police_db.at[6, 'Freguesia'] = 'Santo António'
police_db.at[7, 'Freguesia'] = 'Ajuda'
police_db.at[8, 'Freguesia'] = 'Santa Maria Maior'
police_db.at[9, 'Freguesia'] = 'Arroios'
police_db.at[10, 'Freguesia'] = 'Campo Grande'
police_db.at[11, 'Freguesia'] = 'Belém'
police_db.at[12, 'Freguesia'] = 'Campolide'
police_db.at[13, 'Freguesia'] = 'Misericórdia'
police_db.at[14, 'Freguesia'] = 'Santo António'
police_db.at[15, 'Freguesia'] = 'Olivais'
police_db.at[16, 'Freguesia'] = 'Olivais'
police_db.at[17, 'Freguesia'] = 'Marvila'
police_db.at[18, 'Freguesia'] = 'Marvila'
police_db.at[19, 'Freguesia'] = 'Moscavide'
police_db.at[20, 'Freguesia'] = 'Benfica'
police_db.at[21, 'Freguesia'] = 'Benfica'
police_db.at[22, 'Freguesia'] = 'Belém'
police_db.at[23, 'Freguesia'] = 'Belém'
police_db.at[24, 'Freguesia'] = 'Estrela'
police_db.at[25, 'Freguesia'] = 'Benfica'
police_db.at[26, 'Freguesia'] = 'Benfica'

# %%
police_db.at[27, 'Freguesia'] = 'Campo Grande'
police_db.at[28, 'Freguesia'] = 'Lumiar'
police_db.at[29, 'Freguesia'] = 'Benfica'
police_db.at[30, 'Freguesia'] = 'Campolide'
police_db.at[31, 'Freguesia'] = 'Carnide'
police_db.at[32, 'Freguesia'] = 'Carnide'
police_db.at[33, 'Freguesia'] = 'Campolide'
police_db.at[34, 'Freguesia'] = 'Lumiar'
police_db.at[35, 'Freguesia'] = 'Carnide'
police_db.at[36, 'Freguesia'] = 'Benfica'
police_db.at[37, 'Freguesia'] = 'Carnide'
police_db.at[38, 'Freguesia'] = 'Alcântara'
police_db.at[39, 'Freguesia'] = 'Campo de Ourique'
police_db.at[40, 'Freguesia'] = 'Belém'
police_db.at[41, 'Freguesia'] = 'Alcântara'
police_db.at[42, 'Freguesia'] = 'Estrela'
police_db.at[43, 'Freguesia'] = 'Santa Maria Maior'
police_db.at[44, 'Freguesia'] = 'Areeiro'

# %%
police_db
# Out:
#                                                  NOME  \
# 0                                         2ª Esquadra
# 1   Divisão Policial de Segurança a Transportes Pú...
# 2     1ª Esquadra de Segurança a Transportes Públicos
# 3                   Esquadra de Investigação Criminal
# 4            Tribunal de Monsanto - Esquadra Especial
# 5     4º Esquadra de Segurança a Transportes Públicos
# 6   Direção Nacional da PSP - Departamento de Arma...
# 7                                Corpo de Intervenção
# 8                                 Esquadra de Turismo
# 9                                    Posto de Polícia
# 10                                   Posto de Polícia
# 11                                   Posto de Polícia
# 12                                  Polícia Municipal
# 13                                        3ª Esquadra
# 14                                    22ª Esquadra LX
# 15                             2ª Divisão Policial LX
# 16    Esquadra de Intervenção e Fiscalização Policial
# 17                                    14ª Esquadra LX
# 18                                    16ª Esquadra LX
# 19                                       40ª Esquadra
# 20                             3ª Divisão Policial LX
# 21                              Esquadra de Segurança
# 22                              Esquadra de Segurança
# 23                              Esquadra de Segurança
# 24                              Esquadra de Segurança
# 25                              Esquadra de Segurança
# 26    Esquadra de Intervenção e Fiscalização Policial
# 27                                    18ª Esquadra LX
# 28                                    19ª Esquadra LX
# 29                                    20ª Esquadra LX
# 30                                    21ª Esquadra LX
# 31                                       32ª Esquadra
# 32                                       36ª Esquadra
# 33                                       37ª Esquadra
# 34                                       41ª Esquadra
# 35                                       42ª Esquadra
# 36                                    43ª Esquadra LX
# 37                                   Posto de Polícia
# 38                                4ª Divisão Policial
# 39                                    24ª Esquadra LX
# 40                                    26ª Esquadra LX
# 41                                    28ª Esquadra LX
# 42                                       30ª Esquadra
# 43                                    10ª Esquadra Lx
# 44                                    12ª Esquadra LX
#
#                                                MORADA CODPOSTAL  \
# 0   Rua da Prata nº 38, 1100-419 Lisboa c/ Rua de ...  1100-524
# 1              Estação CP Rossio Ed. Posto do Comando  1200-147
# 2   Praça do Marquês de Pombal Estação de Metro (M...  1250-161
# 3     Estação CP Rossio, Edifício do Chefe da Estação  1200-147
# 4                Estrada do Forte (Monsanto) Tribunal  1500-624
# 5   Avenida Dom João II, Estação do Oriente Lt. 01...  1990-233
# 6               Travessa da Fábrica dos Pentes 22, 1º  1269-003
# 7                                Calçada da Ajuda, 23  1300-006
# 8               Praça dos Restauradores - Palácio Foz  1250-187
# 9         Rua José António Serrano Bloco Central, R/C  1150-199
# 10  Avenida  Professor Egas Moniz  Hospital de San...  1649-035
# 11  Estrada do Forte do Alto do Duque Hospital S F...  1449-005
# 12                           Rua Cardeal Saraiva, R/C  1070-045
# 13  Rua da Atalaia 138-144, R/C, Rua de O Século  ...  1200-033
# 14                                   Largo do Rato, 1  1250-185
# 15  Rua Cidade de Nampula (antiga Rua B2 de Olivai...  1800-105
# 16         Avenida Cidade Lourenço Marques, Praceta A  1800-093
# 17                          Rua Luiz Pacheco Lote 105  1950-244
# 18                Avenida João Paulo II Lote 526, R/C  1950-159
# 19  Rua Ilha dos Amores, Lote 43901-J, Parque das ...  1990-371
# 20                          Rua André de Resende, R/C  1500-040
# 21                              Palácio de Belém, s/n  1349-022
# 22                            Praça de São Bento, s/n  1249-068
# 23                Rua Professor Gomes Teixeira 2, R/C  1350-265
# 24                       Rua da Imprensa à Estrela, 4  1200-888
# 25         Avenida João Crisóstomo Casa da Moeda, R/C  1500-624
# 26                            Rua André de Resende, 1  1500-040
# 27                    Rua Afonso Lopes Vieira 2A, R/C  1700-093
# 28  Rua Professor Luís Reis dos Santos, Lote H - 4...  1600-641
# 29                             Rua André de Resende 1  1500-040
# 30  Rua Marquês de Fronteira Tribunal da Policia, ...  1098-001
# 31  Rua Alfredo Ferraz (antigo Impasse B1 do Bairr...  1600-003
# 32  Rua Prof. Miller Guerra (antigo Impasse A do B...  1600-647
# 33                Rua Miguel Ângelo de Blasco 25, R/C  1070-181
# 34  Rua Maria José da Guia, 14 B - Bairro da Cruz ...  1750-358
# 35                          Rua Manuela Porto, 14 - A  1500-422
# 36  Rua do Azevinho (Rua B) Quarteirão Central B -...  1500-536
# 37  Rua Albert Einstein (antiga R Norte - C.C.Colo...  1500-676
# 38                            Largo do Calvário 6, 1º  1300-113
# 39                            Rua Azedo Gneco 84, R/C  1350-039
# 40               Praça Afonso de Albuquerque PSP, R/C  1300-004
# 41                           Largo do Calvário 6, R/C  1300-113
# 42                             Rua Miguel Lupi 6, R/C  1200-725
# 43                            Rua de Arroios, 164 - A  1000-061
# 44                          Rua Américo Durão, 3, A-B  1900-063
#
#             Freguesia
# 0         São Nicolau
# 1       Santo António
# 2   Santa Maria Maior
# 3       Santo António
# 4             Benfica
# 5             Olivais
# 6       Santo António
# 7               Ajuda
# 8   Santa Maria Maior
# 9             Arroios
# 10       Campo Grande
# 11              Belém
# 12          Campolide
# 13       Misericórdia
# 14      Santo António
# 15            Olivais
# 16            Olivais
# 17            Marvila
# 18            Marvila
# 19          Moscavide
# 20            Benfica
# 21            Benfica
# 22              Belém
# 23              Belém
# 24            Estrela
# 25            Benfica
# 26            Benfica
# 27       Campo Grande
# 28             Lumiar
# 29            Benfica
# 30          Campolide
# 31            Carnide
# 32            Carnide
# 33          Campolide
# 34             Lumiar
# 35            Carnide
# 36            Benfica
# 37            Carnide
# 38          Alcântara
# 39   Campo de Ourique
# 40              Belém
# 41          Alcântara
# 42            Estrela
# 43  Santa Maria Maior
# 44            Areeiro

# %% [markdown]
# ## Merge Population into Freguesia

# %%
freguesias_db.head()

# 1 Create a dictionary for matching old FREGUESIAs with new Fregeusias with New as keys and List of old as value
dict_change=freguesias_db[['CURRENT FREGUESIAS','OLD FREGUESIAS']].to_dict('list')

liste_old_Fregue = [s.split(' + ') for s in freguesias_db['OLD FREGUESIAS']]
liste_new_Fregue = freguesias_db['CURRENT FREGUESIAS']

dictionaryNEW_OLD = dict(zip(liste_new_Fregue,liste_old_Fregue))

#print(len(dictionaryNEW_OLD))


# 2change list of values = OLD FREGUESIAS to key and add New Frequesias as value
dictionaryOLD_NEW={} 
count=-1
for value in dictionaryNEW_OLD.values():
    count +=1
    for x in value:
        dictionaryOLD_NEW[x]=list(dictionaryNEW_OLD.keys())[count]
#print(len(dictionaryOLD_NEW))
        
# 3 import dictionary in to a dataframe
dfOLD_NEW=pd.DataFrame.from_dict(dictionaryOLD_NEW, orient='index', columns=['CURRENT FREGUESIAS']).reset_index()
dfOLD_NEW.columns=['FREGUESIAS','CURRENT FREGUESIAS']
#print(dfOLD_NEW)

# 4 add the New FREGUESIAs to the population dataframe
pop_new = pd.merge(pop_db, dfOLD_NEW, on='FREGUESIAS', how ='left')
#print(pop_new)
#print(pop_db)
# 5 group the population by the new FREGUESIAs
pop_grouped = pop_new.groupby(['CURRENT FREGUESIAS'], as_index=False).agg({'TOTAL RESIDENTS':'sum'})

# 6 merge the population with the frequesias
freg_with_pop= pd.merge(freguesias_db, pop_grouped, on='CURRENT FREGUESIAS')
freg_with_pop
# Out:
#          CURRENT FREGUESIAS         AREA  \
# 0             SANTO ANTÓNIO   1494348.58
# 1                   MARVILA   7122521.90
# 2                     AJUDA   2876647.11
# 3                   AREEIRO   1719002.47
# 4         SANTA MARIA MAIOR   3011591.52
# 5                  ALVALADE   5341751.02
# 6                     BELÉM  10426948.88
# 7                   ESTRELA   4604095.97
# 8                   ARROIOS   2127871.88
# 9               SANTA CLARA   3355562.58
# 10           AVENIDAS NOVAS   2994523.99
# 11                  CARNIDE   3688827.32
# 12  SÃO DOMINGOS DE BENFICA   4294403.21
# 13                    BEATO   2483775.04
# 14                CAMPOLIDE   2774372.95
# 15                ALCÂNTARA   5074843.76
# 16         CAMPO DE OURIQUE   1651405.17
# 17              SÃO VICENTE   1985855.99
# 18                  OLIVAIS   8088293.95
# 19             MISERICÓRDIA   2192198.78
# 20                   LUMIAR   6574930.77
# 21          PENHA DE FRANÇA   2710760.87
# 22                  BENFICA   8024544.82
#
#                                        OLD FREGUESIAS  TOTAL RESIDENTS
# 0            CORAÇÃO DE JESUS + SÃO JOSÉ + SÃO MAMEDE            11855
# 1                                             MARVILA            38102
# 2                                               AJUDA            15584
# 3                     ALTO DO PINA + SÃO JOÃO DE DEUS            20131
# 4   CASTELO + MADALENA + MÁRTIRES + SACRAMENTO + S...            12961
# 5         ALVALADE + CAMPO GRANDE + SÃO JOÃO DE BRITO            31110
# 6         SANTA MARIA DE BELÉM + SÃO FRANCISCO XAVIER            16561
# 7                    LAPA + PRAZERES + SANTOS-O-VELHO            20116
# 8                 ANJOS + PENA + SÃO JORGE DE ARROIOS            32262
# 9                               AMEIXOEIRA + CHARNECA             9935
# 10  NOSSA SENHORA DE FÁTIMA + SÃO SEBASTIÃO DA PED...            21625
# 11                                            CARNIDE            23316
# 12                            SÃO DOMINGOS DE BENFICA            33745
# 13                                              BEATO            12429
# 14                                          CAMPOLIDE            15460
# 15                                          ALCÂNTARA            13943
# 16                   SANTA ISABEL + SANTO CONDESTÁVEL            22132
# 17       GRAÇA + SANTA ENGRÁCIA + SÃO VICENTE DE FORA            14575
# 18                            SANTA MARIA DOS OLIVAIS            51036
# 19   ENCARNAÇÃO + MERCÊS + SANTA CATARINA + SÃO PAULO            13041
# 20                                             LUMIAR            41163
# 21                         PENHA DE FRANÇA + SÃO JOÃO            27967
# 22                                            BENFICA            36821

# %% [markdown]
# ## Cleaning Average Cost of Living

# %%
cost_of_living_db = pd.read_excel('Avg cost of living.xlsx')

cost_of_living_db['Current Freguesias'] = cost_of_living_db['Current Freguesias'].str.upper()
cost_of_living_db.columns = ['CURRENT FREGUESIAS', 'AVERAGE RENT IN EUROS']

cost_of_living_db.head()
# Out:
#   CURRENT FREGUESIAS  AVERAGE RENT IN EUROS
# 0              AJUDA                 271.61
# 1          ALCÂNTARA                 308.09
# 2           ALVALADE                 381.83
# 3            AREEIRO                 410.26
# 4            ARROIOS                 372.80

# %%
freq_with_pop_COSTofLi = pd.merge(freg_with_pop, cost_of_living_db, on='CURRENT FREGUESIAS', how='left')
freq_with_pop_COSTofLi
#print(len(freg_with_pop))
#print(len(freq_with_pop_COSTofLi))
# Out:
#          CURRENT FREGUESIAS         AREA  \
# 0             SANTO ANTÓNIO   1494348.58
# 1                   MARVILA   7122521.90
# 2                     AJUDA   2876647.11
# 3                   AREEIRO   1719002.47
# 4         SANTA MARIA MAIOR   3011591.52
# 5                  ALVALADE   5341751.02
# 6                     BELÉM  10426948.88
# 7                   ESTRELA   4604095.97
# 8                   ARROIOS   2127871.88
# 9               SANTA CLARA   3355562.58
# 10           AVENIDAS NOVAS   2994523.99
# 11                  CARNIDE   3688827.32
# 12  SÃO DOMINGOS DE BENFICA   4294403.21
# 13                    BEATO   2483775.04
# 14                CAMPOLIDE   2774372.95
# 15                ALCÂNTARA   5074843.76
# 16         CAMPO DE OURIQUE   1651405.17
# 17              SÃO VICENTE   1985855.99
# 18                  OLIVAIS   8088293.95
# 19             MISERICÓRDIA   2192198.78
# 20                   LUMIAR   6574930.77
# 21          PENHA DE FRANÇA   2710760.87
# 22                  BENFICA   8024544.82
#
#                                        OLD FREGUESIAS  TOTAL RESIDENTS  \
# 0            CORAÇÃO DE JESUS + SÃO JOSÉ + SÃO MAMEDE            11855
# 1                                             MARVILA            38102
# 2                                               AJUDA            15584
# 3                     ALTO DO PINA + SÃO JOÃO DE DEUS            20131
# 4   CASTELO + MADALENA + MÁRTIRES + SACRAMENTO + S...            12961
# 5         ALVALADE + CAMPO GRANDE + SÃO JOÃO DE BRITO            31110
# 6         SANTA MARIA DE BELÉM + SÃO FRANCISCO XAVIER            16561
# 7                    LAPA + PRAZERES + SANTOS-O-VELHO            20116
# 8                 ANJOS + PENA + SÃO JORGE DE ARROIOS            32262
# 9                               AMEIXOEIRA + CHARNECA             9935
# 10  NOSSA SENHORA DE FÁTIMA + SÃO SEBASTIÃO DA PED...            21625
# 11                                            CARNIDE            23316
# 12                            SÃO DOMINGOS DE BENFICA            33745
# 13                                              BEATO            12429
# 14                                          CAMPOLIDE            15460
# 15                                          ALCÂNTARA            13943
# 16                   SANTA ISABEL + SANTO CONDESTÁVEL            22132
# 17       GRAÇA + SANTA ENGRÁCIA + SÃO VICENTE DE FORA            14575
# 18                            SANTA MARIA DOS OLIVAIS            51036
# 19   ENCARNAÇÃO + MERCÊS + SANTA CATARINA + SÃO PAULO            13041
# 20                                             LUMIAR            41163
# 21                         PENHA DE FRANÇA + SÃO JOÃO            27967
# 22                                            BENFICA            36821
#
#     AVERAGE RENT IN EUROS
# 0                  386.26
# 1                  212.79
# 2                  271.61
# 3                  410.26
# 4                  273.20
# 5                  381.83
# 6                  431.90
# 7                  376.04
# 8                  372.80
# 9                  280.87
# 10                 421.45
# 11                 317.42
# 12                 412.61
# 13                 255.74
# 14                 325.87
# 15                 308.09
# 16                 344.07
# 17                 285.35
# 18                 330.69
# 19                 321.15
# 20                 428.16
# 21                 330.75
# 22                 324.95

# %%
# rename main file
main_db= freq_with_pop_COSTofLi

# %% [markdown]
# ## Creating Density column

# %%
main_db['DENSITY'] = main_db['AREA'] / main_db['TOTAL RESIDENTS']
main_db.head(10)
# Out:
#   CURRENT FREGUESIAS         AREA  \
# 0      SANTO ANTÓNIO   1494348.58
# 1            MARVILA   7122521.90
# 2              AJUDA   2876647.11
# 3            AREEIRO   1719002.47
# 4  SANTA MARIA MAIOR   3011591.52
# 5           ALVALADE   5341751.02
# 6              BELÉM  10426948.88
# 7            ESTRELA   4604095.97
# 8            ARROIOS   2127871.88
# 9        SANTA CLARA   3355562.58
#
#                                       OLD FREGUESIAS  TOTAL RESIDENTS  \
# 0           CORAÇÃO DE JESUS + SÃO JOSÉ + SÃO MAMEDE            11855
# 1                                            MARVILA            38102
# 2                                              AJUDA            15584
# 3                    ALTO DO PINA + SÃO JOÃO DE DEUS            20131
# 4  CASTELO + MADALENA + MÁRTIRES + SACRAMENTO + S...            12961
# 5        ALVALADE + CAMPO GRANDE + SÃO JOÃO DE BRITO            31110
# 6        SANTA MARIA DE BELÉM + SÃO FRANCISCO XAVIER            16561
# 7                   LAPA + PRAZERES + SANTOS-O-VELHO            20116
# 8                ANJOS + PENA + SÃO JORGE DE ARROIOS            32262
# 9                              AMEIXOEIRA + CHARNECA             9935
#
#    AVERAGE RENT IN EUROS     DENSITY
# 0                 386.26  126.052179
# 1                 212.79  186.933019
# 2                 271.61  184.589779
# 3                 410.26   85.390814
# 4                 273.20  232.357960
# 5                 381.83  171.705272
# 6                 431.90  629.608652
# 7                 376.04  228.877310
# 8                 372.80   65.955982
# 9                 280.87  337.751644

# %% [markdown]
# ## Summary Statistics

# %%
main_db.describe()
# Out:
#                AREA  TOTAL RESIDENTS  AVERAGE RENT IN EUROS     DENSITY
# count  2.300000e+01        23.000000              23.000000   23.000000
# mean   4.113873e+06     23298.695652             339.298261  192.542209
# std    2.437941e+06     11194.274906              60.571762  119.686334
# min    1.494349e+06      9935.000000             212.790000   65.955982
# 25%    2.337987e+06     14259.000000             296.720000  131.755635
# 50%    3.011592e+06     20131.000000             330.690000  168.100512
# 75%    5.208297e+06     31686.000000             384.045000  208.885498
# max    1.042695e+07     51036.000000             431.900000  629.608652

# %% [markdown]
# ## Relative values

# %%
# 1 per person


# 2 per Density

# %% [markdown]
# ## Idea for Binning

# %%
#### apply for relative Values!!
mpg_labels= [x for x in range(1,12)]
main_db['BINNED POPULATION'] = pd.qcut(main_db['TOTAL RESIDENTS'], 11, labels = mpg_labels)

main_db
# Out:
#          CURRENT FREGUESIAS         AREA  \
# 0             SANTO ANTÓNIO   1494348.58
# 1                   MARVILA   7122521.90
# 2                     AJUDA   2876647.11
# 3                   AREEIRO   1719002.47
# 4         SANTA MARIA MAIOR   3011591.52
# 5                  ALVALADE   5341751.02
# 6                     BELÉM  10426948.88
# 7                   ESTRELA   4604095.97
# 8                   ARROIOS   2127871.88
# 9               SANTA CLARA   3355562.58
# 10           AVENIDAS NOVAS   2994523.99
# 11                  CARNIDE   3688827.32
# 12  SÃO DOMINGOS DE BENFICA   4294403.21
# 13                    BEATO   2483775.04
# 14                CAMPOLIDE   2774372.95
# 15                ALCÂNTARA   5074843.76
# 16         CAMPO DE OURIQUE   1651405.17
# 17              SÃO VICENTE   1985855.99
# 18                  OLIVAIS   8088293.95
# 19             MISERICÓRDIA   2192198.78
# 20                   LUMIAR   6574930.77
# 21          PENHA DE FRANÇA   2710760.87
# 22                  BENFICA   8024544.82
#
#                                        OLD FREGUESIAS  TOTAL RESIDENTS  \
# 0            CORAÇÃO DE JESUS + SÃO JOSÉ + SÃO MAMEDE            11855
# 1                                             MARVILA            38102
# 2                                               AJUDA            15584
# 3                     ALTO DO PINA + SÃO JOÃO DE DEUS            20131
# 4   CASTELO + MADALENA + MÁRTIRES + SACRAMENTO + S...            12961
# 5         ALVALADE + CAMPO GRANDE + SÃO JOÃO DE BRITO            31110
# 6         SANTA MARIA DE BELÉM + SÃO FRANCISCO XAVIER            16561
# 7                    LAPA + PRAZERES + SANTOS-O-VELHO            20116
# 8                 ANJOS + PENA + SÃO JORGE DE ARROIOS            32262
# 9                               AMEIXOEIRA + CHARNECA             9935
# 10  NOSSA SENHORA DE FÁTIMA + SÃO SEBASTIÃO DA PED...            21625
# 11                                            CARNIDE            23316
# 12                            SÃO DOMINGOS DE BENFICA            33745
# 13                                              BEATO            12429
# 14                                          CAMPOLIDE            15460
# 15                                          ALCÂNTARA            13943
# 16                   SANTA ISABEL + SANTO CONDESTÁVEL            22132
# 17       GRAÇA + SANTA ENGRÁCIA + SÃO VICENTE DE FORA            14575
# 18                            SANTA MARIA DOS OLIVAIS            51036
# 19   ENCARNAÇÃO + MERCÊS + SANTA CATARINA + SÃO PAULO            13041
# 20                                             LUMIAR            41163
# 21                         PENHA DE FRANÇA + SÃO JOÃO            27967
# 22                                            BENFICA            36821
#
#     AVERAGE RENT IN EUROS     DENSITY BINNED POPULATION
# 0                  386.26  126.052179                 1
# 1                  212.79  186.933019                10
# 2                  271.61  184.589779                 4
# 3                  410.26   85.390814                 6
# 4                  273.20  232.357960                 2
# 5                  381.83  171.705272                 8
# 6                  431.90  629.608652                 5
# 7                  376.04  228.877310                 5
# 8                  372.80   65.955982                 9
# 9                  280.87  337.751644                 1
# 10                 421.45  138.475098                 6
# 11                 317.42  158.210127                 7
# 12                 412.61  127.260430                 9
# 13                 255.74  199.837078                 1
# 14                 325.87  179.454913                 4
# 15                 308.09  363.970721                 3
# 16                 344.07   74.616174                 7
# 17                 285.35  136.250840                 3
# 18                 330.69  158.482129                11
# 19                 321.15  168.100512                 2
# 20                 428.16  159.729144                11
# 21                 330.75   96.927124                 8
# 22                 324.95  217.933919                10

# %% [markdown]
# ## Rank of Cost of Living

# %%
mpg_labels= [x for x in range(1,23)]
main_db['RANK COST OF LIVING'] = pd.qcut(main_db['AVERAGE RENT IN EUROS'], 22, labels = mpg_labels)

main_db
# Out:
#          CURRENT FREGUESIAS         AREA  \
# 0             SANTO ANTÓNIO   1494348.58
# 1                   MARVILA   7122521.90
# 2                     AJUDA   2876647.11
# 3                   AREEIRO   1719002.47
# 4         SANTA MARIA MAIOR   3011591.52
# 5                  ALVALADE   5341751.02
# 6                     BELÉM  10426948.88
# 7                   ESTRELA   4604095.97
# 8                   ARROIOS   2127871.88
# 9               SANTA CLARA   3355562.58
# 10           AVENIDAS NOVAS   2994523.99
# 11                  CARNIDE   3688827.32
# 12  SÃO DOMINGOS DE BENFICA   4294403.21
# 13                    BEATO   2483775.04
# 14                CAMPOLIDE   2774372.95
# 15                ALCÂNTARA   5074843.76
# 16         CAMPO DE OURIQUE   1651405.17
# 17              SÃO VICENTE   1985855.99
# 18                  OLIVAIS   8088293.95
# 19             MISERICÓRDIA   2192198.78
# 20                   LUMIAR   6574930.77
# 21          PENHA DE FRANÇA   2710760.87
# 22                  BENFICA   8024544.82
#
#                                        OLD FREGUESIAS  TOTAL RESIDENTS  \
# 0            CORAÇÃO DE JESUS + SÃO JOSÉ + SÃO MAMEDE            11855
# 1                                             MARVILA            38102
# 2                                               AJUDA            15584
# 3                     ALTO DO PINA + SÃO JOÃO DE DEUS            20131
# 4   CASTELO + MADALENA + MÁRTIRES + SACRAMENTO + S...            12961
# 5         ALVALADE + CAMPO GRANDE + SÃO JOÃO DE BRITO            31110
# 6         SANTA MARIA DE BELÉM + SÃO FRANCISCO XAVIER            16561
# 7                    LAPA + PRAZERES + SANTOS-O-VELHO            20116
# 8                 ANJOS + PENA + SÃO JORGE DE ARROIOS            32262
# 9                               AMEIXOEIRA + CHARNECA             9935
# 10  NOSSA SENHORA DE FÁTIMA + SÃO SEBASTIÃO DA PED...            21625
# 11                                            CARNIDE            23316
# 12                            SÃO DOMINGOS DE BENFICA            33745
# 13                                              BEATO            12429
# 14                                          CAMPOLIDE            15460
# 15                                          ALCÂNTARA            13943
# 16                   SANTA ISABEL + SANTO CONDESTÁVEL            22132
# 17       GRAÇA + SANTA ENGRÁCIA + SÃO VICENTE DE FORA            14575
# 18                            SANTA MARIA DOS OLIVAIS            51036
# 19   ENCARNAÇÃO + MERCÊS + SANTA CATARINA + SÃO PAULO            13041
# 20                                             LUMIAR            41163
# 21                         PENHA DE FRANÇA + SÃO JOÃO            27967
# 22                                            BENFICA            36821
#
#     AVERAGE RENT IN EUROS     DENSITY BINNED POPULATION RANK COST OF LIVING
# 0                  386.26  126.052179                 1                  17
# 1                  212.79  186.933019                10                   1
# 2                  271.61  184.589779                 4                   2
# 3                  410.26   85.390814                 6                  18
# 4                  273.20  232.357960                 2                   3
# 5                  381.83  171.705272                 8                  16
# 6                  431.90  629.608652                 5                  22
# 7                  376.04  228.877310                 5                  15
# 8                  372.80   65.955982                 9                  14
# 9                  280.87  337.751644                 1                   4
# 10                 421.45  138.475098                 6                  20
# 11                 317.42  158.210127                 7                   7
# 12                 412.61  127.260430                 9                  19
# 13                 255.74  199.837078                 1                   1
# 14                 325.87  179.454913                 4                  10
# 15                 308.09  363.970721                 3                   6
# 16                 344.07   74.616174                 7                  13
# 17                 285.35  136.250840                 3                   5
# 18                 330.69  158.482129                11                  11
# 19                 321.15  168.100512                 2                   8
# 20                 428.16  159.729144                11                  21
# 21                 330.75   96.927124                 8                  12
# 22                 324.95  217.933919                10                   9

# %% [markdown]
# ## Compare Social Infrastructure and Cost of Living
